# %% [markdown]
# <pre>
# <center><b><h1>Data Mining</b></center>
# <center><b><h1>DataSet - 1</b></center>
# <pre>

# %%
import pandas as pd

# %% [markdown]
# <h1>DataSet - 1</h1>

# %%
dataFrame = pd.read_csv('OnlineRetail.csv' , sep=',' ,encoding = 'ISO-8859-1')
dataFrame
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# <h3>Read First 20 Data from given DataSet</h3>

# %%
dataFrame.head(20)
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5     536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6     536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7     536366     22633               HAND WARMER UNION JACK         6
# 8     536366     22632            HAND WARMER RED POLKA DOT         6
# 9     536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10    536367     22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11    536367     22748            POPPY'S PLAYHOUSE KITCHEN         6
# ...

# %% [markdown]
# <h3>Read last 20 Data from given Dataset</h3>

# %%
dataFrame.tail(20)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 541889    581585     22466       FAIRY TALE COTTAGE NIGHT LIGHT        12
# 541890    581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
# 541891    581586     23275     SET OF 3 HANGING OWLS OLLIE BEAK        24
# 541892    581586     21217        RED RETROSPOT ROUND CAKE TINS        24
# 541893    581586     20685                DOORMAT RED RETROSPOT        10
# 541894    581587     22631             CIRCUS PARADE LUNCH BOX         12
# 541895    581587     22556       PLASTERS IN TIN CIRCUS PARADE         12
# 541896    581587     22555            PLASTERS IN TIN STRONGMAN        12
# 541897    581587     22728            ALARM CLOCK BAKELIKE PINK         4
# 541898    581587     22727            ALARM CLOCK BAKELIKE RED          4
# 541899    581587     22726           ALARM CLOCK BAKELIKE GREEN         4
# 541900    581587     22730           ALARM CLOCK BAKELIKE IVORY         4
# ...

# %% [markdown]
# <h3>Summarize the given Dataset</h3>

# %%
dataFrame.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# <h3>Describe DataType of each Column</h3>

# %%
dataFrame.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %% [markdown]
# <h3>Provide Information of the given Dataset</h3>

# %%
dataFrame.info
# Out:
# <bound method DataFrame.info of        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %% [markdown]
# <h3>Calculate mean of the DataSet</h3>

# %%
dataFrame.mean
# Out:
# <bound method DataFrame.mean of        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %% [markdown]
# <h3>Calculate median of the DataSet</h3>

# %%
dataFrame.median
# Out:
# <bound method DataFrame.median of        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %% [markdown]
# <h3>Calculate mode of the DataSet</h3>

# %%
dataFrame.mode
# Out:
# <bound method DataFrame.mode of        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %% [markdown]
# <h3>Print StockCode column of given DataSet</h3>

# %%
print('StockCode Column')
dataFrame['StockCode']
# Out:
# StockCode Column
# 0         85123A
# 1          71053
# 2         84406B
# 3         84029G
# 4         84029E
#            ...
# 541904     22613
# 541905     22899
# 541906     23254
# 541907     23255
# 541908     22138
# Name: StockCode, Length: 541909, dtype: object

# %% [markdown]
# <h3>Number of Records in DataSet</h3>

# %%
dataFrame.shape
# Out:
# (541909, 8)

# %% [markdown]
# <h3>Record of Dataset where quantity is not 6</h3>

# %%
dataFrame[dataFrame['Quantity'] != 6]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 2         536365    84406B     CREAM CUPID HEARTS COAT HANGER         8
# 5         536365     22752       SET 7 BABUSHKA NESTING BOXES         2
# 9         536367     84879      ASSORTED COLOUR BIRD ORNAMENT        32
# 12        536367     22749  FELTCRAFT PRINCESS CHARLOTTE DOLL         8
# 15        536367     22623      BOX OF VINTAGE JIGSAW BLOCKS          3
# ...          ...       ...                                ...       ...
# 541903    581587     23256        CHILDRENS CUTLERY SPACEBOY          4
# 541904    581587     22613        PACK OF 20 SPACEBOY NAPKINS        12
# 541906    581587     23254      CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255    CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138      BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# <h3>Sum of Quantity Column.</h3>

# %%
dataFrame['Quantity'].sum()
# Out:
# 5176450

# %% [markdown]
# <h3>Records of dataSet where country is <b>United Kingdom.</b></h3>

# %%
(dataFrame['Country'] == 'United Kingdom').count()
# Out:
# 541909

# %%
dataFrame.value_counts()
# Out:
# InvoiceNo  StockCode  Description                          Quantity  InvoiceDate       UnitPrice  CustomerID  Country
# 555524     22698      PINK REGENCY TEACUP AND SAUCER        1        6/5/2011 11:37    2.95       16923.0     United Kingdom    20
#            22697      GREEN REGENCY TEACUP AND SAUCER       1        6/5/2011 11:37    2.95       16923.0     United Kingdom    12
# 572861     22775      PURPLE DRAWERKNOB ACRYLIC EDWARDIAN   12       10/26/2011 12:46  1.25       14102.0     United Kingdom     8
# 572344     M          Manual                                48       10/24/2011 10:43  1.50       14607.0     United Kingdom     6
# 578289     23395      BELLE JARDINIERE CUSHION COVER        1        11/23/2011 14:07  3.75       17841.0     United Kingdom     6
#                                                                                                                                 ..
# ...

# %%
dataFrame['Quantity'].max()
# Out:
# 80995

# %%
dataFrame['Quantity'].min()
# Out:
# -80995

# %%
dataFrame.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
dataFrame.shape[1] #no. of columns
# Out:
# 8

# %%
dataFrame.nunique()
# Out:
# InvoiceNo      25900
# StockCode       4070
# Description     4223
# Quantity         722
# InvoiceDate    23260
# UnitPrice       1630
# CustomerID      4372
# Country           38
# dtype: int64

# %%
#maximun quantitied product

grp = dataFrame.groupby('Description').sum()
grp = grp.sort_values(['Quantity'] , ascen
                      
                      ding = False)
grp.head(1)
# Out:
#                                                                            InvoiceNo  \
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS  5366155366185368305368395368565368765370505371...
#
#                                                                            StockCode  \
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS  8407784077840778407784077840778407784077840778...
#
#                                    Quantity  \
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     53847
#
#                                                                          InvoiceDate  \
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS  12/2/2010 10:0912/2/2010 10:1712/2/2010 17:381...
#
#                                    UnitPrice  CustomerID  \
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     173.39   7297844.0
#
#                                                                              Country
# Description
# ...

# %%
(dataFrame.isnull()).sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
dataFrame.index
# Out:
# RangeIndex(start=0, stop=541909, step=1)

# %%
dataFrame.std
# Out:
# <bound method DataFrame.std of        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %%
dataFrame.corr(numeric_only=True)
# Out:
#             Quantity  UnitPrice  CustomerID
# Quantity    1.000000  -0.001235    -0.00360
# UnitPrice  -0.001235   1.000000    -0.00456
# CustomerID -0.003600  -0.004560     1.00000

# %%
dataFrame.cov(numeric_only=True)
# Out:
#                 Quantity    UnitPrice    CustomerID
# Quantity    47559.391409   -26.058761 -1.534050e+03
# UnitPrice     -26.058761  9362.469164 -5.415793e+02
# CustomerID  -1534.050176  -541.579276  2.936426e+06
