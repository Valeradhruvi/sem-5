# %% [markdown]
# ## DATA SET -2

# %% [markdown]
# <h3>Import Libraries</h3>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %% [markdown]
# <h3>Import Dataset from csv</h3>

# %%
data=pd.read_csv("heart.csv")

# %%
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# <h3>Print top 10 Rows</h3>

# %%
data.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# ...

# %% [markdown]
# <h3>Print bottom 10 rows</h3>

# %%
data.tail(10)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1015   58    1   0       128   216    0        0      131      1      2.2
# 1016   65    1   3       138   282    1        0      174      0      1.4
# 1017   53    1   0       123   282    0        1       95      1      2.0
# 1018   41    1   0       110   172    0        0      158      0      0.0
# 1019   47    1   0       112   204    0        1      143      0      0.1
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1015      1   3     3       0
# 1016      1   1     2       0
# 1017      1   2     3       0
# ...

# %% [markdown]
# <h3>Value count of target column</h3>

# %%
data.target.value_counts()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %% [markdown]
# <h3>Dimention of DataSet (total rows and columns</h3>

# %%
data.shape
# Out:
# (1025, 14)

# %% [markdown]
# <h3>Print Age Column of DataSet</h3>

# %%
print('AGE Column')
data['age']
# Out:
# AGE Column
# 0       52
# 1       53
# 2       70
# 3       61
# 4       62
#         ..
# 1020    59
# 1021    60
# 1022    47
# 1023    50
# 1024    54
# Name: age, Length: 1025, dtype: int64

# %% [markdown]
# <h3>Summary of Dataset</h3>

# %%
data.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %% [markdown]
# <h3>Types of each Column</h3>

# %%
data.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %% [markdown]
# <h3>Unique Age Count</h3>

# %%
data.age.nunique()
# Out:
# 41

# %% [markdown]
# <h3>Summary Type 2</h3>

# %%
data.info
# Out:
# <bound method DataFrame.info of       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# ...

# %% [markdown]
# <h3>Mean of Age Column</h3>

# %%
data['age'].mean()
# Out:
# 54.43414634146342

# %% [markdown]
# <h3>Mode of Age Column</h3>

# %%
data['age'].mode()
# Out:
# 0    58
# Name: age, dtype: int64

# %% [markdown]
# <h3>Median of Age Column</h3>

# %%
data['age'].median()
# Out:
# age          56.0
# sex           1.0
# cp            1.0
# trestbps    130.0
# chol        240.0
# fbs           0.0
# restecg       1.0
# thalach     152.0
# exang         0.0
# oldpeak       0.8
# slope         1.0
# ca            0.0
# thal          2.0
# target        1.0
# dtype: float64

# %% [markdown]
# <h3>Show all id where target column is 1</h3>

# %%
data[data['target']==1]
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 5      58    0   0       100   248    0        0      122      0      1.0
# 10     71    0   0       112   149    0        1      125      0      1.6
# 12     34    0   1       118   210    0        1      192      0      0.7
# 15     34    0   1       118   210    0        1      192      0      0.7
# 16     51    0   2       140   308    0        0      142      0      1.5
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1011   45    1   1       128   308    0        0      170      0      0.0
# 1014   44    0   2       108   141    0        1      175      0      0.6
# 1019   47    1   0       112   204    0        1      143      0      0.1
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
#
#       slope  ca  thal  target
# 5         1   0     2       1
# ...

# %% [markdown]
# <h3>Correlation of DataSet</h3>

# %%
data.corr(numeric_only=True)
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.103240 -0.071966  0.271121  0.219823  0.121243
# sex      -0.103240  1.000000 -0.041119 -0.078974 -0.198258  0.027200
# cp       -0.071966 -0.041119  1.000000  0.038177 -0.081641  0.079294
# trestbps  0.271121 -0.078974  0.038177  1.000000  0.127977  0.181767
# chol      0.219823 -0.198258 -0.081641  0.127977  1.000000  0.026917
# fbs       0.121243  0.027200  0.079294  0.181767  0.026917  1.000000
# restecg  -0.132696 -0.055117  0.043581 -0.123794 -0.147410 -0.104051
# thalach  -0.390227 -0.049365  0.306839 -0.039264 -0.021772 -0.008866
# exang     0.088163  0.139157 -0.401513  0.061197  0.067382  0.049261
# oldpeak   0.208137  0.084687 -0.174733  0.187434  0.064880  0.010859
# slope    -0.169105 -0.026666  0.131633 -0.120445 -0.014248 -0.061902
# ca        0.271551  0.111729 -0.176206  0.104554  0.074259  0.137156
# thal      0.072297  0.198424 -0.163341  0.059276  0.100244 -0.042177
# ...

# %% [markdown]
# <h3>Covariance Of DadtaSet</h3>

# %% [markdown]
# data.cov(numeric_only=True)

# %% [markdown]
# <h3>Count of doc where age is 58</h3>

# %%
(data['age'] == 58).count()
# Out:
# 1025

# %% [markdown]
# <h3>Max of Age Column</h3>

# %%
data['age'].max()
# Out:
# 77

# %% [markdown]
# <h3>Min of Age Coumn</h3>

# %%
data['age'].min()
# Out:
# 29

# %% [markdown]
# <h3>Print whole column where target is 1</h3>

# %%
data[data['target']==1]
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 5      58    0   0       100   248    0        0      122      0      1.0
# 10     71    0   0       112   149    0        1      125      0      1.6
# 12     34    0   1       118   210    0        1      192      0      0.7
# 15     34    0   1       118   210    0        1      192      0      0.7
# 16     51    0   2       140   308    0        0      142      0      1.5
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1011   45    1   1       128   308    0        0      170      0      0.0
# 1014   44    0   2       108   141    0        1      175      0      0.6
# 1019   47    1   0       112   204    0        1      143      0      0.1
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
#
#       slope  ca  thal  target
# 5         1   0     2       1
# ...

# %% [markdown]
# <h3>Unique item count of Dataset</h3>

# %%
data.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     49
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# target        2
# dtype: int64

# %% [markdown]
# <h3>count of total null values</h3>

# %%
(data.isnull()).sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# <h3>Standard deviation of dataset</h3>

# %%
data.std
# Out:
# <bound method DataFrame.std of       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# ...

# %% [markdown]
# <h3>Print whole column where target is 1 </h3>

# %%
data.groupby('cp').count()
# Out:
#     age  sex  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# cp
# 0   497  497       497   497  497      497      497    497      497    497
# 1   167  167       167   167  167      167      167    167      167    167
# 2   284  284       284   284  284      284      284    284      284    284
# 3    77   77        77    77   77       77       77     77       77     77
#
#      ca  thal  target
# cp
# 0   497   497     497
# 1   167   167     167
# 2   284   284     284
# 3    77    77      77

# %% [markdown]
# <h3>Print Indexs made in trans</h3>

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1025, step=1)

# %%
data['age'].hist(bins = 8,edgecolor = 'black')
plt.title("Histogram of Age")
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.scatter(data['trestbps'],data['chol'],alpha=0.5)
plt.xlabel('Trestbps')
plt.ylabel('Chol')
plt.title('Scatter Plot of Trestbps vs Chol')
plt.show()
